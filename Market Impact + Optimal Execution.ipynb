# %%
import numpy as np
import matplotlib.pyplot as plt
n_list=np.arange(0,6)
trades1=[1000000,416759.0435788, 248490.3740846, 153092.9124578, 101947.4202105, 79710.2496683]
trades2=[1000000,464607.1113991, 276910.6670991, 150444.5783691, 72562.2363361, 35475.4067966]
trades3=[1000000,437852.5622832, 260564.0996536, 151603.2007264, 89177.6857162, 60802.4516207]

# %%
plt.plot(n_list,trades1,label='0.02λ')
plt.plot(n_list,trades2,label='0.06λ')
plt.plot(n_list,trades3,label='0.04λ')
plt.xlabel('Time Periods')
plt.ylabel('Position Remaining')
leg = plt.legend(loc='upper right')
plt.title('Optimal Trading Trajectories (λ is risk parameter)')
plt.show()
